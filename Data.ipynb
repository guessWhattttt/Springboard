# %%
import pandas as pd

# %%
Columbus=pd.read_csv('listings.csv')
Columbus.head()
# Out:
#        id                                              name  host_id  \
# 0   90676                  Short North - Italianate Cottage   483306
# 1  543140                Private queen bedroom 1 - N.Campus  2350409
# 2  591101   The Bellows' Studio Loft  (3rd floor apartment)  2889677
# 3  681145  2 bed/Safe/Quiet/Clean/Ample Parking/OSU/Laundry  3468444
# 4  923248  1 Single Bed in a Shared Coed Dorm at the Hostel  4965048
#
#        host_name  neighbourhood_group          neighbourhood  latitude  \
# 0  Audra & Lacey                  NaN  Near North/University  39.98394
# 1         Edward                  NaN  Near North/University  40.01243
# 2           Gail                  NaN              Near East  39.96086
# 3          Vicki                  NaN  Near North/University  40.01898
# 4         Mathew                  NaN  Near North/University  40.01259
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
Columbus2=pd.read_csv('listings (1).csv')
Columbus2.head()
# Out:
#        id                                              name  host_id  \
# 0   90676                  Short North - Italianate Cottage   483306
# 1  543140                Private queen bedroom 1 - N.Campus  2350409
# 2  591101   The Bellows' Studio Loft  (3rd floor apartment)  2889677
# 3  681145  2 bed/Safe/Quiet/Clean/Ample Parking/OSU/Laundry  3468444
# 4  923248  1 Single Bed in a Shared Coed Dorm at the Hostel  4965048
#
#        host_name  neighbourhood_group          neighbourhood  latitude  \
# 0  Audra & Lacey                  NaN  Near North/University  39.98394
# 1         Edward                  NaN  Near North/University  40.01243
# 2           Gail                  NaN              Near East  39.96086
# 3          Vicki                  NaN  Near North/University  40.01898
# 4         Mathew                  NaN  Near North/University  40.01259
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
Columbus3=pd.read_csv('listings (4).csv')
Columbus3.head()
# Out:
#        id                                              name  host_id  \
# 0   90676                  Short North - Italianate Cottage   483306
# 1  543140                Private queen bedroom 1 - N.Campus  2350409
# 2  591101   The Bellows' Studio Loft  (3rd floor apartment)  2889677
# 3  681145  2 bed/Safe/Quiet/Clean/Ample Parking/OSU/Laundry  3468444
# 4  923248  1 Single Bed in a Shared Coed Dorm at the Hostel  4965048
#
#        host_name  neighbourhood_group          neighbourhood  latitude  \
# 0  Audra & Lacey                  NaN  Near North/University  39.98394
# 1         Edward                  NaN  Near North/University  40.01243
# 2           Gail                  NaN              Near East  39.96086
# 3          Vicki                  NaN  Near North/University  40.01898
# 4         Mathew                  NaN  Near North/University  40.01259
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %% [markdown]
# # Columbus

# %%
ColumbusT = pd.concat([Columbus, Columbus2,Columbus3], axis=1, join='outer')
ColumbusT
# Out:
#             id                                              name    host_id  \
# 0      90676.0                  Short North - Italianate Cottage   483306.0
# 1     543140.0                Private queen bedroom 1 - N.Campus  2350409.0
# 2     591101.0   The Bellows' Studio Loft  (3rd floor apartment)  2889677.0
# 3     681145.0  2 bed/Safe/Quiet/Clean/Ample Parking/OSU/Laundry  3468444.0
# 4     923248.0  1 Single Bed in a Shared Coed Dorm at the Hostel  4965048.0
# ...        ...                                               ...        ...
# 1553       NaN                                               NaN        NaN
# 1554       NaN                                               NaN        NaN
# 1555       NaN                                               NaN        NaN
# 1556       NaN                                               NaN        NaN
# 1557       NaN                                               NaN        NaN
#
# ...

# %% [markdown]
# # Chicago, Illinois

# %%
Chicago# Columbus=pd.read_csv('listings (5).csv.gz')
Chicago
# Out:
#             id                            listing_url       scrape_id  \
# 0         2384      https://www.airbnb.com/rooms/2384  20210419135634
# 1         4505      https://www.airbnb.com/rooms/4505  20210419135634
# 2         7126      https://www.airbnb.com/rooms/7126  20210419135634
# 3         9811      https://www.airbnb.com/rooms/9811  20210419135634
# 4        10945     https://www.airbnb.com/rooms/10945  20210419135634
# ...        ...                                    ...             ...
# 6381  49259148  https://www.airbnb.com/rooms/49259148  20210419135634
# 6382  49259244  https://www.airbnb.com/rooms/49259244  20210419135634
# 6383  49264091  https://www.airbnb.com/rooms/49264091  20210419135634
# 6384  49273283  https://www.airbnb.com/rooms/49273283  20210419135634
# 6385  49275573  https://www.airbnb.com/rooms/49275573  20210419135634
#
#      last_scraped                                               name  \
# ...

# %% [markdown]
# # Austin

# %%
Austin=pd.read_csv('listings (6).csv.gz')
Austin
# Out:
#              id                            listing_url       scrape_id  \
# 0          2265      https://www.airbnb.com/rooms/2265  20210416175518
# 1          5245      https://www.airbnb.com/rooms/5245  20210416175518
# 2          5456      https://www.airbnb.com/rooms/5456  20210416175518
# 3          5636      https://www.airbnb.com/rooms/5636  20210416175518
# 4          5769      https://www.airbnb.com/rooms/5769  20210416175518
# ...         ...                                    ...             ...
# 10104  49232460  https://www.airbnb.com/rooms/49232460  20210416175518
# 10105  49239675  https://www.airbnb.com/rooms/49239675  20210416175518
# 10106  49239676  https://www.airbnb.com/rooms/49239676  20210416175518
# 10107  49241337  https://www.airbnb.com/rooms/49241337  20210416175518
# 10108  49243766  https://www.airbnb.com/rooms/49243766  20210416175518
#
#       last_scraped                                               name  \
# ...
